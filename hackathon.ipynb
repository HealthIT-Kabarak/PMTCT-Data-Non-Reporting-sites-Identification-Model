# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#READING HTS FILE
hts_df = pd.read_excel('hst.xlsx')
hts_df.head()
# Out:
#    facilityuid            facility     code              ward  \
# 0  aCOEeeYEcsO  Rabondo Dispensary  14019.0   West sakwa Ward
# 1  aCOEeeYEcsO  Rabondo Dispensary  14019.0   West sakwa Ward
# 2  aWpElDmioIw     Kuja Dispensary  13724.0  North sakwa Ward
# 3  aWpElDmioIw     Kuja Dispensary  13724.0  North sakwa Ward
# 4  aWpElDmioIw     Kuja Dispensary  13724.0  North sakwa Ward
#
#           sub_county         county    indicator  \
# 0  Awendo Sub County  Migori County  JiuqbydCIcy
# 1  Awendo Sub County  Migori County  OePJt8CcZ0d
# 2  Awendo Sub County  Migori County  JiuqbydCIcy
# 3  Awendo Sub County  Migori County  pkShOkgNQt2
# 4  Awendo Sub County  Migori County  YXJf27jfkvS
#
#                     Indicator Name  period  dhis2_value  datim_value  \
# 0  MOH 731 Tested_20-24(F) HV01-07  2019Q4         33.0         87.0
# 1       MOH 731 Tested_1-9 HV01-01  2020Q1         14.0         13.0
# 2  MOH 731 Tested_20-24(F) HV01-07  2019Q4         15.0         53.0
# 3  MOH 731 Tested_20-24(M) HV01-06  2020Q2          9.0         10.0
# 4  MOH 731 Tested_15-19(F) HV01-05  2019Q4          7.0         39.0
#
#    difference
# 0       -54.0
# 1         1.0
# 2       -38.0
# 3         NaN
# 4       -32.0

# %%
#READING PMTCT
pmtct_df = pd.read_excel('pmtct.xlsx')
pmtct_df.head()
# Out:
#    facilityuid                       facility     code               ward  \
# 0  SZnkrFoimi2         Kugitimo Health Centre  13723.0  Nyabasi east Ward
# 1  xt2lltkTLza  Ntimaru Sub-District Hospital  13858.0  Ntimaru west Ward
# 2  NoZjHcIDHGW      Kegonga District Hospital  13663.0  Nyabasi east Ward
# 3  SZnkrFoimi2         Kugitimo Health Centre  13723.0  Nyabasi east Ward
# 4  xt2lltkTLza  Ntimaru Sub-District Hospital  13858.0  Ntimaru west Ward
#
#               sub_county         county    indicator  \
# 0  Kuria East Sub County  Migori County  ETX9cUWF43c
# 1  Kuria East Sub County  Migori County  ETX9cUWF43c
# 2  Kuria East Sub County  Migori County  qSgLzXh46n9
# 3  Kuria East Sub County  Migori County  ETX9cUWF43c
# 4  Kuria East Sub County  Migori County  ETX9cUWF43c
#
#                                       indicator_name  period  dhis2_value  \
# 0         MOH 731  Initial test at ANC       HV02-04  2020Q1         64.0
# 1         MOH 731  Initial test at ANC       HV02-04  2019Q4        119.0
# 2  MOH 731  Known Positive at 1st  ANC       HV02-03  2020Q2          1.0
# 3         MOH 731  Initial test at ANC       HV02-04  2020Q2         46.0
# 4         MOH 731  Initial test at ANC       HV02-04  2020Q1        194.0
#
#    datim_value
# 0         64.0
# 1        124.0
# 2          1.0
# 3         45.0
# 4        191.0

# %%
#MERGING TWO DATAFRAMES THAT IS HTS_DF AND PMTCT_DF 

merged_df = pd.merge(hts_df, pmtct_df, on='facilityuid')

merged_df.to_csv('Combined.csv', index = False)
#cleaning
merged_df = merged_df.dropna()
merged_df.drop_duplicates(subset=['facilityuid'], inplace=True)
merged_df.drop(["ward_x","ward_y"], inplace=True, axis=1)


merged_df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      facilityuid              facility_x   code_x           sub_county_x  \
# 0    aCOEeeYEcsO      Rabondo Dispensary  14019.0      Awendo Sub County
# 162  aWpElDmioIw         Kuja Dispensary  13724.0      Awendo Sub County
# 292  B8Y8xuk4MFf      Ngo'nga Dispensary  17052.0      Awendo Sub County
# 436  bi747puqsrA    Matoso Health Clinic  13793.0     Nyatike Sub County
# 595  BSIVRetkq9o  Getongoroma Dispensary  13569.0  Kuria West Sub County
#
#           county_x  indicator_x                   Indicator Name period_x  \
# 0    Migori County  JiuqbydCIcy  MOH 731 Tested_20-24(F) HV01-07   2019Q4
# 162  Migori County  JiuqbydCIcy  MOH 731 Tested_20-24(F) HV01-07   2019Q4
# 292  Migori County  gMICOUtzqRb  MOH 731 Tested_10-14(F) HV01-03   2019Q4
# 436  Migori County  gMICOUtzqRb  MOH 731 Tested_10-14(F) HV01-03   2019Q4
# 595  Migori County  JiuqbydCIcy  MOH 731 Tested_20-24(F) HV01-07   2019Q4
#
#      dhis2_value_x  datim_value_x  difference              facility_y  \
# 0             33.0           87.0       -54.0      Rabondo Dispensary
# 162           15.0           53.0       -38.0         Kuja Dispensary
# 292            3.0            5.0        -2.0      Ngo'nga Dispensary
# 436            6.0           11.0        -5.0    Matoso Health Clinic
# 595           33.0           70.0       -37.0  Getongoroma Dispensary
#
#       code_y           sub_county_y       county_y  indicator_y  \
# 0    14019.0      Awendo Sub County  Migori County  ETX9cUWF43c
# 162  13724.0      Awendo Sub County  Migori County  ETX9cUWF43c
# 292  17052.0      Awendo Sub County  Migori County  qSgLzXh46n9
# 436  13793.0     Nyatike Sub County  Migori County  qSgLzXh46n9
# 595  13569.0  Kuria West Sub County  Migori County  ETX9cUWF43c
#
#                                         indicator_name period_y  \
# 0           MOH 731  Initial test at ANC       HV02-04   2019Q4
# 162         MOH 731  Initial test at ANC       HV02-04   2019Q4
# 292  MOH 731  Known Positive at 1st  ANC       HV02-03   2019Q4
# 436  MOH 731  Known Positive at 1st  ANC       HV02-03   2020Q1
# 595         MOH 731  Initial test at ANC       HV02-04   2020Q1
#
#      dhis2_value_y  datim_value_y
# 0             74.0           70.0
# 162           22.0           27.0
# 292            3.0            3.0
# 436            9.0            9.0
# 595           59.0           58.0

# %%
# Create target variable for classification - sites not reporting tests

merged_df['not_reporting_tests'] = 1 - merged_df['dhis2_value_x']
#merged_df['not_reporting_tests'] = merged_df['datim_value_x'] - merged_df['dhis2_value_x']
merged_df.dropna(inplace =True)

#NOT REPORTED
#print(merged_df['not_reporting_tests']) 

# Select relevant features for classification

features  = ['dhis2_value_y', 'datim_value_y','dhis2_value_x', 'datim_value_x']


# Create feature matrix and target variable
X = merged_df[features]
y = merged_df['not_reporting_tests']

# check if there are any NaN values in X or y
if X.isna().sum().sum() > 0 or y.isna().sum().sum() > 0:
    print("Rows with NaN values in X or y:")
    print(merged_df[X.isna().any(axis=1) | y.isna()])
    # drop rows with NaN values in X or y
    merged_df.dropna(inplace=True, subset=features+['not_reporting_tests'])

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1,random_state=42)

# Create decision tree classifier
clf = DecisionTreeClassifier(random_state=42)



clf.fit(X_train, y_train)

# Export decision tree visualization to file

feature_names = [str(features[0]), str(features[1]),str(features[2]),str(features[3])]
class_names = sorted( y.unique())


class_name_str = [str(cls) for cls in class_names]

 # convert all class names to string
tree.export_graphviz(clf, out_file='pmtct-sample_data.dot', 
                     feature_names=feature_names,
                     class_names=class_name_str,
                     label='all',
                     rounded=True,
                     filled=True)


#Predict the target variable for the test set
y_pred = clf.predict(X_test)

print(y_pred)
print("\n")
# Evaluate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# [ -19.  -40.  -32.  -32.  -71.  -89.   -8.  -43. -129.  -60.  -47.   -2.
#   -16.]
#
#
# Accuracy: 0.6923076923076923
